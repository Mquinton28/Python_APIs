# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
import pandas as pd
import json
import requests
import matplotlib.pyplot as plt
import numpy as np
import config
import os
from config import weather_api_key
from citipy import citipy

url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q={city}"

# %% [markdown]
# ## Generate Cities List

# %%
from scipy import integrate

cities = []
latitude_longitude = []
#Latitude & Longitude ranges
coords_lat_range = (-90, 90)
coords_lng_range = (-180, 180)
        
coords_lat = np.random.uniform(low=-90, high=90, size=1500)
coords_lng = np.random.uniform(low=-180, high=180, size=1500)
latitude_longitude = zip(coords_lat, coords_lng)

for latitude_longitude in latitude_longitude:
    city = citipy.nearest_city(latitude_longitude[0],latitude_longitude[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
        
len(cities)

# # To slice the list in for loop do for value in x[0:3]
# Out:
# 592

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Testing cell
b = requests.get(query_url + "Miami").json()
b['coord']['lon']
# Out:
# -80.19

# %%
b
# Out:
# {'coord': {'lon': -80.19, 'lat': 25.77},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 27.03,
#   'feels_like': 29.32,
#   'temp_min': 25.56,
#   'temp_max': 28.33,
#   'pressure': 1014,
#   'humidity': 78},
#  'visibility': 10000,
#  'wind': {'speed': 4.1, 'deg': 70},
#  'clouds': {'all': 90},
#  'dt': 1603160514,
#  'sys': {'type': 1,
#   'id': 4896,
#   'country': 'US',
#   'sunrise': 1603106501,
#   'sunset': 1603147754},
#  'timezone': -14400,
#  'id': 4164138,
#  'name': 'Miami',
#  'cod': 200}

# %%
# set up lists to hold response info
city_data = []
city_counter = 0

#Loop through the list of cities and perform a request for data on each

for city in cities:
    response = requests.get(query_url + city).json()
    city_counter = city_counter + 1
    try:
        A={'lat': response['coord']['lat'],
          'long': response['coord']['lon'],
          'temp': response['main']['temp'],
          'city': city}
        
        city_data.append(A)
        
        print(f'{city_counter} {city}')
        
    except:
        print(f'{city_counter} {city} not found')
# Out:
# 1 kahului
# 2 hilo
# 3 kruisfontein
# 4 rikitea
# 5 tasiilaq
# 6 kodiak
# 7 lorengau
# 8 ushuaia
# 9 hobart
# 10 labuhan
# 11 bredasdorp
# 12 sao filipe
# 13 hithadhoo
# 14 pachino
# 15 east london
# 16 chokurdakh
# 17 coruripe
# 18 oussouye
# 19 vavoua
# 20 nanortalik
# 21 busselton
# 22 barentsburg not found
# 23 saldanha
# 24 san pedro
# 25 kirakira
# 26 samusu not found
# 27 pala
# 28 skalistyy not found
# 29 lompoc
# 30 mogadishu
# 31 norman wells
# 32 hermanus
# 33 kamina
# 34 tuktoyaktuk
# 35 sitia
# 36 punta arenas
# 37 puerto ayora
# 38 mataura
# 39 bengkulu
# 40 petauke
# 41 twin falls
# 42 mahajanga
# 43 chuy
# 44 nikolskoye
# 45 new norfolk
# 46 kota kinabalu
# 47 palmer
# 48 ahipara
# 49 karkal
# 50 broome
# 51 sentyabrskiy not found
# 52 albany
# 53 nanzhou
# 54 barrow
# 55 vostok
# 56 morros
# 57 half moon bay
# 58 lolua not found
# 59 atambua
# 60 mount gambier
# 61 cabo san lucas
# 62 saint anthony
# 63 illapel
# 64 sitka
# 65 jamestown
# 66 esperance
# 67 vaini
# 68 faanui
# 69 nizhneyansk not found
# 70 la asuncion
# 71 bethel
# 72 mahebourg
# 73 vaitape
# 74 saint-joseph
# 75 port alfred
# 76 georgetown
# 77 eureka
# 78 arraial do cabo
# 79 robertsport
# 80 souillac
# 81 yerbogachen
# 82 qui nhon
# 83 antsohihy
# 84 mys shmidta not found
# 85 emba
# 86 russell
# 87 tiksi
# 88 ashcroft
# 89 port hardy
# 90 logan
# 91 boulder city
# 92 turayf
# 93 bathsheba
# 94 kapaa
# 95 dikson
# 96 shingu
# 97 tuatapere
# 98 treinta y tres
# 99 thinadhoo
# 100 batticaloa
# 101 carnarvon
# 102 cam ranh
# 103 bluff
# 104 tsihombe not found
# 105 atuona
# 106 butaritari
# 107 nioro
# 108 ler
# 109 avarua
# 110 zambezi
# 111 atar
# 112 watertown
# 113 rameswaram
# 114 la ronge
# 115 christchurch
# 116 marystown
# 117 konskie
# 118 san quintin
# 119 salcininkai
# 120 puerto madryn
# 121 talara
# 122 qaanaaq
# 123 kandrian
# 124 touros
# 125 mandera
# 126 tidore not found
# 127 mundra
# 128 viligili not found
# 129 illoqqortoormiut not found
# 130 burns lake
# 131 kushima
# 132 provideniya
# 133 ilulissat
# 134 buraydah
# 135 port elizabeth
# 136 roald
# 137 attawapiskat not found
# 138 kimbe
# 139 yellowknife
# 140 geraldton
# 141 changli
# 142 ngorongoro
# 143 teya
# 144 luderitz
# 145 pangnirtung
# 146 jalu
# 147 artyom
# 148 zaozerne
# 149 airai
# 150 niono
# 151 leningradskiy
# 152 ippy
# 153 yeniseysk
# 154 monte san pietro
# 155 lazurne
# 156 lebu
# 157 maumere
# 158 comodoro rivadavia
# 159 tarabuco
# 160 taolanaro not found
# 161 saint-philippe
# 162 kavaratti
# 163 can
# 164 kiunga
# 165 severo-kurilsk
# 166 saskylakh
# 167 torbay
# 168 sao gabriel da cachoeira
# 169 belushya guba not found
# 170 obu
# 171 berlevag
# 172 matamoros
# 173 bireun
# 174 tatawin
# 175 tshela
# 176 miandrivazo
# 177 san patricio
# 178 kuching
# 179 san cristobal
# 180 bhowali
# 181 hunza not found
# 182 kaitangata
# 183 aragats
# 184 grand river south east not found
# 185 ardalstangen
# 186 luanda
# 187 kidal
# 188 cap malheureux
# 189 namibe
# 190 fairbanks
# 191 nurota
# 192 siuna
# 193 bartica
# 194 grand gaube
# 195 trofors
# 196 pimentel
# 197 korla
# 198 inuvik
# 199 kendari
# 200 pinheiro
# 201 yatou
# 202 poso
# 203 kaseda
# 204 san rafael
# 205 yanam
# 206 mar del plata
# 207 aklavik
# 208 victoria
# 209 nalut
# 210 buchanan
# 211 finschhafen
# 212 ponta do sol
# 213 lazaro cardenas
# 214 klaksvik
# 215 meulaboh
# 216 pevek
# 217 naze
# 218 paamiut
# 219 ruatoria not found
# 220 clyde river
# 221 castro
# 222 pacific grove
# 223 longyearbyen
# 224 westpunt not found
# 225 khatanga
# 226 kununurra
# 227 adre
# 228 hasaki
# 229 talnakh
# 230 haapiti
# 231 vardo
# 232 jacareacanga
# 233 tura
# 234 zeya
# 235 waingapu
# 236 shu
# 237 cidreira
# 238 hobyo
# 239 semey
# 240 dingle
# 241 marzuq
# 242 ahmadpur
# 243 shiki
# 244 comrat
# 245 valdivia
# 246 yulara
# 247 erenhot
# 248 murgab
# 249 novo aripuana
# 250 vila do maio
# 251 whitehorse
# 252 dovolnoye
# 253 tigil
# 254 narsaq
# 255 bambous virieux
# 256 tuy hoa
# 257 palabuhanratu not found
# 258 katsuura
# 259 saiha
# 260 nelson bay
# 261 muros
# 262 trzic
# 263 cape town
# 264 saint george
# 265 yomitan not found
# 266 rawson
# 267 conde
# 268 prudy
# 269 komsomolskiy
# 270 kaeo
# 271 longlac not found
# 272 lata
# 273 rawicz
# 274 ribeira grande
# 275 boende
# 276 sept-iles
# 277 grand-santi
# 278 padang
# 279 bereda
# 280 san jose
# 281 xudat
# 282 ninh binh
# 283 hailey
# 284 ust-kuyga
# 285 wadi musa
# 286 pran buri
# 287 pandan
# 288 mackay
# 289 kazachinskoye
# 290 sumbawa not found
# 291 kuhdasht
# 292 umzimvubu not found
# 293 upernavik
# 294 constitucion
# 295 daru
# 296 sobolevo
# 297 mahibadhoo
# 298 havelock
# 299 lasa
# 300 juegang
# 301 beloha
# 302 nizhniy odes
# 303 tumannyy not found
# 304 tolaga bay
# 305 salalah
# 306 maloshuyka not found
# 307 lensk
# 308 tasbuget not found
# 309 madera
# 310 adamovka
# 311 natal
# 312 faya
# 313 kuytun
# 314 nago
# 315 lahaina
# 316 katangli
# 317 garelochhead
# 318 potoru
# 319 cabot
# 320 orsha
# 321 ozgon not found
# 322 alamogordo
# 323 cayenne
# 324 metkovic
# 325 tucuman
# 326 sherbakul
# 327 moron
# 328 pelham
# 329 pisco
# 330 richards bay
# 331 benatky nad jizerou
# 332 kadykchan not found
# 333 jaque
# 334 caraballeda
# 335 mount isa
# 336 baherden
# 337 baoqing
# 338 michigan city
# 339 okato
# 340 ayan
# 341 guerrero negro
# 342 zenzeli
# 343 codrington
# 344 saint-leu
# 345 bonavista
# 346 kismayo
# 347 verkhnyaya sinyachikha
# 348 abbeville
# 349 katherine
# 350 dzilam gonzalez
# 351 mucurapo
# 352 sioux lookout
# 353 morehead
# 354 kautokeino
# 355 sulangan
# 356 ixtapa
# 357 adrar
# 358 lovozero
# 359 kapoeta
# 360 amderma not found
# 361 margate
# 362 cabedelo
# 363 ambo
# 364 santa maria
# 365 dauphin
# 366 partizanskoye
# 367 rincon
# 368 maragogi
# 369 nome
# 370 maniitsoq
# 371 iquique
# 372 petropavlovsk-kamchatskiy
# 373 brigantine
# 374 talmenka
# 375 tambul not found
# 376 bosaso
# 377 high level
# 378 pankrushikha
# 379 samalaeulu not found
# 380 walvis bay
# 381 saleaula not found
# 382 mana
# 383 warqla not found
# 384 izumo
# 385 gimbi
# 386 port hedland
# 387 crab hill not found
# 388 kemijarvi
# 389 alyangula
# 390 balaguer
# 391 slave lake
# 392 okhotsk
# 393 snezhnogorsk
# 394 quatre cocos
# 395 deputatskiy
# 396 rundu
# 397 praya
# 398 pisticci
# 399 shakawe
# 400 lagoa
# 401 kuryk
# 402 saint-pierre
# 403 kavieng
# 404 talakan
# 405 oktyabrskoye
# 406 palpa
# 407 oro valley
# 408 north bend
# 409 sisimiut
# 410 zhigansk
# 411 vientiane
# 412 saint-augustin
# 413 coihaique
# 414 muravlenko
# 415 bontang
# 416 qaqortoq
# 417 vestbygda not found
# 418 urumqi
# 419 camacha
# 420 kaniama
# 421 vao
# 422 banjarmasin
# 423 akyab
# 424 kedougou
# 425 joshimath
# 426 muroto
# 427 lubao
# 428 palana
# 429 catuday
# 430 camabatela
# 431 stornoway
# 432 tabuk
# 433 sur
# 434 tres arroyos
# 435 shumskiy
# 436 gat
# 437 bushehr
# 438 amazar
# 439 nemuro
# 440 kupang
# 441 urengoy
# 442 filadelfia
# 443 flinders
# 444 sakakah
# 445 trelew
# 446 liusha
# 447 shadegan
# 448 phan thiet
# 449 majene
# 450 maldonado
# 451 vastervik not found
# 452 pozhva
# 453 thio
# 454 kizilskoye
# 455 haines junction
# 456 caravelas
# 457 gidrotorf
# 458 okha
# 459 chicama
# 460 vitry-le-francois
# 461 dzaoudzi
# 462 dunedin
# 463 acapulco
# 464 jambi
# 465 enterprise
# 466 lavrentiya
# 467 kharan
# 468 amuntai
# 469 saint-michel-des-saints
# 470 moose factory
# 471 severnoye
# 472 wattegama
# 473 garden acres
# 474 cherskiy
# 475 matara
# 476 ostrovnoy
# 477 thompson
# 478 moree
# 479 kalas
# 480 eaglesfield
# 481 anglet
# 482 liverpool
# 483 bandarbeyla
# 484 sorland
# 485 laguna
# 486 xinqing
# 487 yanchukan not found
# 488 kalabo
# 489 biryusinsk
# 490 puksoozero
# 491 mezen
# 492 el sauzal
# 493 shimanovsk
# 494 colchester
# 495 petropavlovka
# 496 hamilton
# 497 ostersund
# 498 husavik
# 499 esmeraldas
# 500 portel
# 501 vagur
# 502 riachao das neves
# 503 portland
# 504 angoche
# 505 coahuayana
# 506 gorkovskoye not found
# 507 pizarro
# 508 las choapas
# 509 la brea
# 510 kuusamo
# 511 abu dhabi
# 512 kathmandu
# 513 bom jesus da lapa
# 514 omsukchan
# 515 oga
# 516 buala
# 517 imeni zhelyabova
# 518 pinawa
# 519 cockburn town
# 520 salisbury
# 521 mingguang
# 522 vaitupu not found
# 523 ketchikan
# 524 kitale
# 525 vila franca do campo
# 526 ugoofaaru
# 527 boden
# 528 hofn
# 529 belaya gora
# 530 mehamn
# 531 karamay not found
# 532 coquimbo
# 533 wilhelmsburg
# 534 anito
# 535 satitoa not found
# 536 lufilufi
# 537 harper
# 538 abalak
# 539 vredendal
# 540 santa cruz
# 541 porto santo
# 542 west wendover
# 543 ghatal
# 544 bulgan
# 545 aksu
# 546 mazagao
# 547 beringovskiy
# 548 yarim
# 549 palu
# 550 kieta
# 551 sattahip
# 552 zhangzhou
# 553 anuradhapura
# 554 shush
# 555 salvador
# 556 isaka
# 557 fortuna
# 558 tirur
# 559 lubango
# 560 tukrah
# 561 krasnoselkup
# 562 bryan
# 563 bronnoysund
# 564 iqaluit
# 565 kufstein
# 566 pangody
# 567 maloy
# 568 samandag
# 569 brae
# 570 villazon
# 571 hunsur
# 572 manosque
# 573 labutta not found
# 574 benghazi
# 575 nagar karnul
# 576 yangambi
# 577 ayr
# 578 srednekolymsk
# 579 alto araguaia
# 580 ampanihy
# 581 mazatlan
# 582 nanchang
# 583 jiayuguan
# 584 petersburg
# 585 booue
# 586 pangkalanbuun
# 587 puerto del rosario
# 588 itarema
# 589 libourne
# 590 lajedo
# 591 carballo
# 592 vanimo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weatherpy_data = pd.DataFrame(city_data)
weatherpy_data.head()
# Out:
#      lat    long   temp          city
# 0  20.89 -156.47  28.17       kahului
# 1  19.73 -155.09  25.68          hilo
# 2 -34.00   24.73  15.56  kruisfontein
# 3 -23.12 -134.97  23.50       rikitea
# 4  65.61  -37.64  -2.00      tasiilaq

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
